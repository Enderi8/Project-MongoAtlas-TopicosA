# %%
from connect import db
from pymongo import UpdateOne

modificar = db.libros

# Usando Update estoy Actualizar stock de un libro

res = modificar.update_one(
    {"titulo": "La Ciudad Verde"},
    {"$inc": {"stock": 10}}

)

print(f"Libros modificados: {'Cambios', res.matched_count, 'Total', res.modified_count}")

# %%
for doc in modificar.find({"titulo": "La Ciudad Verde"}):
    print(doc['titulo'], 'Hay', doc['stock'], 'libros')

# %%
# Actualización usando UpdateMany

res2 = modificar.update_many(
    {},
    {'$set': {
        'disponible': True
        }
        }
    )

print('Cambios', res2.matched_count, 'Total', res2.modified_count)
# Out:
# Cambios 45 Total 0

# %%
for doc in modificar.find({'disponible': True}):
    print('Disponible:', doc['disponible'])
# Out:
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True
# Disponible: True

# %%
# Bulk write
operations = [
    UpdateOne(
        {'titulo': 'La Ciudad Verde'},
        {'$set': {'stock': 6}}
    )
]
modificar.bulk_write(operations)
# Out:
# BulkWriteResult({'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': []}, acknowledged=True)

# %%
# Eliminar documentos

from connect import db

eliminar = db.libros
res3 = eliminar.delete_one(
    {'titulo': '1984'}
)   
print('Documentos eliminados:', res3.deleted_count)
# Out:
# Documentos eliminados: 1
